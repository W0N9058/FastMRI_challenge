# %%
import numpy as np
import h5py
import glob
import os
import torch
from utils.common.loss_function import SSIMLoss
import torch.nn.functional as F

class SSIM(SSIMLoss):
    def __init__(self, win_size: int = 7, k1: float = 0.01, k2: float = 0.03):
        super().__init__(win_size, k1, k2)
            
    def forward(self, X, Y, data_range):
        if len(X.shape) != 2:
            raise NotImplementedError('Dimension of first input is {} rather than 2'.format(len(X.shape)))
        if len(Y.shape) != 2:
            raise NotImplementedError('Dimension of first input is {} rather than 2'.format(len(Y.shape)))
            
        X = X.unsqueeze(0).unsqueeze(0)
        Y = Y.unsqueeze(0).unsqueeze(0)
        data_range = torch.tensor([data_range], device=X.device)
        
        C1 = (self.k1 * data_range) ** 2
        C2 = (self.k2 * data_range) ** 2
        ux = F.conv2d(X, self.w)
        uy = F.conv2d(Y, self.w)
        uxx = F.conv2d(X * X, self.w)
        uyy = F.conv2d(Y * Y, self.w)
        uxy = F.conv2d(X * Y, self.w)
        vx = self.cov_norm * (uxx - ux * ux)
        vy = self.cov_norm * (uyy - uy * uy)
        vxy = self.cov_norm * (uxy - ux * uy)
        A1, A2, B1, B2 = (
            2 * ux * uy + C1,
            2 * vxy + C2,
            ux ** 2 + uy ** 2 + C1,
            vx + vy + C2,
        )
        D = B1 * B2
        S = (A1 * A2) / D
        return S.mean()
    

def calculate_ssim(data_path):
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    ssim_calculator = SSIM().to(device=device)
    files = glob.glob(os.path.join(data_path, '*.h5'))
    ssim_values = []

    for file_path in files:
        with h5py.File(file_path, 'r') as hf:
            if 'image_input' in hf and 'image_label' in hf:
                grappa = np.array(hf['image_input'])
                label = np.array(hf['image_label'])
                
                # 데이터의 최대 값으로 data_range 설정
                data_range = max(grappa.max(), label.max())

                # SSIM 계산
                file_ssim_total = 0
                file_slice_count = 0
                for i in range(grappa.shape[0]):
                    grappa_slice = torch.from_numpy(grappa[i]).float().to(device)
                    label_slice = torch.from_numpy(label[i]).float().to(device)
                    ssim_value = ssim_calculator(grappa_slice, label_slice, data_range)
                    file_ssim_total += ssim_value.item()
                    file_slice_count += 1
                
                # 파일별 평균 SSIM 값 계산
                if file_slice_count > 0:
                    file_average_ssim = file_ssim_total / file_slice_count
                    ssim_values.append(file_average_ssim)
                print(f'File {file_path}, Average SSIM: {file_average_ssim}')

    # 전체 파일의 평균 SSIM 값 계산
    overall_average_ssim = np.mean(ssim_values) if ssim_values else 0
    print(f'Overall Average SSIM across all processed files: {overall_average_ssim:.4f}')

if __name__ == '__main__':
    data_path = '/home/Data/train/image'
    calculate_ssim(data_path)
# Out:
# File /home/Data/train/image/brain_acc4_57.h5, Average SSIM: 0.8019585758447647
# File /home/Data/train/image/brain_acc8_1.h5, Average SSIM: 0.770336214452982
# File /home/Data/train/image/brain_acc8_48.h5, Average SSIM: 0.766864504132952
# File /home/Data/train/image/brain_acc4_89.h5, Average SSIM: 0.8292124830186367
# File /home/Data/train/image/brain_acc8_11.h5, Average SSIM: 0.7521143034100533
# File /home/Data/train/image/brain_acc8_116.h5, Average SSIM: 0.7592464126646519
# File /home/Data/train/image/brain_acc8_85.h5, Average SSIM: 0.753747183829546
# File /home/Data/train/image/brain_acc8_107.h5, Average SSIM: 0.7636057324707508
# File /home/Data/train/image/brain_acc5_58.h5, Average SSIM: 0.8009274676442146
# File /home/Data/train/image/brain_acc4_110.h5, Average SSIM: 0.8298081606626511
# File /home/Data/train/image/brain_acc4_71.h5, Average SSIM: 0.8390447907149792
# File /home/Data/train/image/brain_acc8_64.h5, Average SSIM: 0.7491626515984535
# File /home/Data/train/image/brain_acc5_43.h5, Average SSIM: 0.803593073040247
# File /home/Data/train/image/brain_acc5_74.h5, Average SSIM: 0.8065379858016968
# File /home/Data/train/image/brain_acc8_111.h5, Average SSIM: 0.7715455330908298
# File /home/Data/train/image/brain_acc4_113.h5, Average SSIM: 0.8181103430688381
# File /home/Data/train/image/brain_acc8_92.h5, Average SSIM: 0.7236035950481892
# File /home/Data/train/image/brain_acc5_40.h5, Average SSIM: 0.7915423177182674
# File /home/Data/train/image/brain_acc4_1.h5, Average SSIM: 0.8386107981204987
# File /home/Data/train/image/brain_acc5_95.h5, Average SSIM: 0.8080856427550316
# File /home/Data/train/image/brain_acc8_120.h5, Average SSIM: 0.7808812814099448
# File /home/Data/train/image/brain_acc4_42.h5, Average SSIM: 0.8270614854991436
# File /home/Data/train/image/brain_acc5_35.h5, Average SSIM: 0.8171905167400837
# File /home/Data/train/image/brain_acc8_102.h5, Average SSIM: 0.775415450334549
# File /home/Data/train/image/brain_acc5_29.h5, Average SSIM: 0.8084087930619717
# File /home/Data/train/image/brain_acc4_45.h5, Average SSIM: 0.8400602266192436
# File /home/Data/train/image/brain_acc5_107.h5, Average SSIM: 0.8049523644149303
# File /home/Data/train/image/brain_acc8_90.h5, Average SSIM: 0.7775635197758675
# File /home/Data/train/image/brain_acc4_27.h5, Average SSIM: 0.8234595209360123
# File /home/Data/train/image/brain_acc4_103.h5, Average SSIM: 0.8286566436290741
# File /home/Data/train/image/brain_acc4_86.h5, Average SSIM: 0.8524583876132965
# File /home/Data/train/image/brain_acc4_80.h5, Average SSIM: 0.8159468322992325
# File /home/Data/train/image/brain_acc8_6.h5, Average SSIM: 0.7693283297121525
# File /home/Data/train/image/brain_acc4_15.h5, Average SSIM: 0.8235716857016087
# File /home/Data/train/image/brain_acc8_47.h5, Average SSIM: 0.7820061221718788
# File /home/Data/train/image/brain_acc8_74.h5, Average SSIM: 0.7542631030082703
# File /home/Data/train/image/brain_acc5_84.h5, Average SSIM: 0.7806964553892612
# File /home/Data/train/image/brain_acc8_98.h5, Average SSIM: 0.7583451494574547
# File /home/Data/train/image/brain_acc5_37.h5, Average SSIM: 0.7974175587296486
# File /home/Data/train/image/brain_acc5_101.h5, Average SSIM: 0.8140527717769146
# File /home/Data/train/image/brain_acc4_75.h5, Average SSIM: 0.8181813210248947
# File /home/Data/train/image/brain_acc4_29.h5, Average SSIM: 0.8219689950346947
# File /home/Data/train/image/brain_acc5_87.h5, Average SSIM: 0.8135514743626118
# File /home/Data/train/image/brain_acc4_3.h5, Average SSIM: 0.823368489742279
# File /home/Data/train/image/brain_acc5_57.h5, Average SSIM: 0.8177972659468651
# File /home/Data/train/image/brain_acc8_93.h5, Average SSIM: 0.7832965925335884
# File /home/Data/train/image/brain_acc8_76.h5, Average SSIM: 0.7628505751490593
# File /home/Data/train/image/brain_acc5_106.h5, Average SSIM: 0.7983506061136723
# File /home/Data/train/image/brain_acc4_104.h5, Average SSIM: 0.822277270257473
# File /home/Data/train/image/brain_acc5_92.h5, Average SSIM: 0.8057775571942329
# File /home/Data/train/image/brain_acc8_75.h5, Average SSIM: 0.7644148543477058
# File /home/Data/train/image/brain_acc4_116.h5, Average SSIM: 0.8221841603517532
# File /home/Data/train/image/brain_acc4_101.h5, Average SSIM: 0.83995446190238
# File /home/Data/train/image/brain_acc8_39.h5, Average SSIM: 0.7563554719090462
# File /home/Data/train/image/brain_acc4_67.h5, Average SSIM: 0.8336330093443394
# File /home/Data/train/image/brain_acc4_64.h5, Average SSIM: 0.8205142915248871
# File /home/Data/train/image/brain_acc4_44.h5, Average SSIM: 0.8246777713298797
# File /home/Data/train/image/brain_acc8_69.h5, Average SSIM: 0.7576748505234718
# File /home/Data/train/image/brain_acc4_35.h5, Average SSIM: 0.8275388702750206
# File /home/Data/train/image/brain_acc5_67.h5, Average SSIM: 0.7991859093308449
# File /home/Data/train/image/brain_acc8_55.h5, Average SSIM: 0.7650342471897602
# File /home/Data/train/image/brain_acc5_93.h5, Average SSIM: 0.8197598159313202
# File /home/Data/train/image/brain_acc8_21.h5, Average SSIM: 0.7848747484385967
# File /home/Data/train/image/brain_acc5_80.h5, Average SSIM: 0.7897159345448017
# File /home/Data/train/image/brain_acc4_83.h5, Average SSIM: 0.8255908414721489
# File /home/Data/train/image/brain_acc5_11.h5, Average SSIM: 0.7850803832213084
# File /home/Data/train/image/brain_acc8_14.h5, Average SSIM: 0.789278082549572
# File /home/Data/train/image/brain_acc8_115.h5, Average SSIM: 0.7736539430916309
# File /home/Data/train/image/brain_acc8_7.h5, Average SSIM: 0.7680059783160686
# File /home/Data/train/image/brain_acc4_98.h5, Average SSIM: 0.8305895105004311
# File /home/Data/train/image/brain_acc8_114.h5, Average SSIM: 0.772045835852623
# File /home/Data/train/image/brain_acc8_24.h5, Average SSIM: 0.7664689645171165
# File /home/Data/train/image/brain_acc4_13.h5, Average SSIM: 0.8151639141142368
# File /home/Data/train/image/brain_acc5_21.h5, Average SSIM: 0.8152098059654236
# File /home/Data/train/image/brain_acc5_14.h5, Average SSIM: 0.7969836518168449
# File /home/Data/train/image/brain_acc4_85.h5, Average SSIM: 0.813338253647089
# File /home/Data/train/image/brain_acc5_2.h5, Average SSIM: 0.8228848725557327
# File /home/Data/train/image/brain_acc4_72.h5, Average SSIM: 0.8375704698264599
# File /home/Data/train/image/brain_acc4_61.h5, Average SSIM: 0.8279820121824741
# File /home/Data/train/image/brain_acc4_10.h5, Average SSIM: 0.8265211544930935
# File /home/Data/train/image/brain_acc8_15.h5, Average SSIM: 0.7590769417583942
# File /home/Data/train/image/brain_acc4_40.h5, Average SSIM: 0.849450592483793
# File /home/Data/train/image/brain_acc5_28.h5, Average SSIM: 0.8215555064380169
# File /home/Data/train/image/brain_acc5_49.h5, Average SSIM: 0.7915103770792484
# File /home/Data/train/image/brain_acc5_81.h5, Average SSIM: 0.7993059568107128
# File /home/Data/train/image/brain_acc5_90.h5, Average SSIM: 0.8108615130186081
# File /home/Data/train/image/brain_acc4_9.h5, Average SSIM: 0.8319889977574348
# File /home/Data/train/image/brain_acc5_70.h5, Average SSIM: 0.8194037899374962
# File /home/Data/train/image/brain_acc4_26.h5, Average SSIM: 0.8317370265722275
# File /home/Data/train/image/brain_acc4_66.h5, Average SSIM: 0.8334653303027153
# File /home/Data/train/image/brain_acc8_44.h5, Average SSIM: 0.7626681551337242
# File /home/Data/train/image/brain_acc4_107.h5, Average SSIM: 0.8133501298725605
# File /home/Data/train/image/brain_acc4_22.h5, Average SSIM: 0.8306228034198284
# File /home/Data/train/image/brain_acc5_46.h5, Average SSIM: 0.8139779716730118
# File /home/Data/train/image/brain_acc4_109.h5, Average SSIM: 0.894585445523262
# File /home/Data/train/image/brain_acc4_92.h5, Average SSIM: 0.857726201415062
# File /home/Data/train/image/brain_acc4_4.h5, Average SSIM: 0.8273088186979294
# File /home/Data/train/image/brain_acc8_34.h5, Average SSIM: 0.7832038812339306
# File /home/Data/train/image/brain_acc8_19.h5, Average SSIM: 0.7405457645654678
# File /home/Data/train/image/brain_acc5_55.h5, Average SSIM: 0.8073380999267101
# File /home/Data/train/image/brain_acc5_7.h5, Average SSIM: 0.8066653795540333
# File /home/Data/train/image/brain_acc5_42.h5, Average SSIM: 0.8094055865492139
# File /home/Data/train/image/brain_acc4_82.h5, Average SSIM: 0.8356549479067326
# File /home/Data/train/image/brain_acc5_62.h5, Average SSIM: 0.8027659170329571
# File /home/Data/train/image/brain_acc4_63.h5, Average SSIM: 0.848251860588789
# File /home/Data/train/image/brain_acc4_16.h5, Average SSIM: 0.8249196149408817
# File /home/Data/train/image/brain_acc4_74.h5, Average SSIM: 0.8229426182806492
# File /home/Data/train/image/brain_acc8_100.h5, Average SSIM: 0.8231402933597565
# File /home/Data/train/image/brain_acc4_117.h5, Average SSIM: 0.8405193723738194
# File /home/Data/train/image/brain_acc5_114.h5, Average SSIM: 0.8044367618858814
# File /home/Data/train/image/brain_acc4_33.h5, Average SSIM: 0.8233740888535976
# File /home/Data/train/image/brain_acc4_43.h5, Average SSIM: 0.7815665192902088
# File /home/Data/train/image/brain_acc4_60.h5, Average SSIM: 0.8350749015808105
# File /home/Data/train/image/brain_acc8_31.h5, Average SSIM: 0.7535795941948891
# File /home/Data/train/image/brain_acc8_36.h5, Average SSIM: 0.7568027153611183
# File /home/Data/train/image/brain_acc8_12.h5, Average SSIM: 0.7591664455831051
# File /home/Data/train/image/brain_acc8_35.h5, Average SSIM: 0.7530576325953007
# File /home/Data/train/image/brain_acc5_86.h5, Average SSIM: 0.8064718022942543
# File /home/Data/train/image/brain_acc4_34.h5, Average SSIM: 0.8324457593262196
# File /home/Data/train/image/brain_acc8_41.h5, Average SSIM: 0.7609341479837894
# File /home/Data/train/image/brain_acc4_47.h5, Average SSIM: 0.8235982246696949
# File /home/Data/train/image/brain_acc8_68.h5, Average SSIM: 0.7529959119856358
# File /home/Data/train/image/brain_acc8_50.h5, Average SSIM: 0.7456844337284565
# File /home/Data/train/image/brain_acc4_32.h5, Average SSIM: 0.8392738476395607
# File /home/Data/train/image/brain_acc4_28.h5, Average SSIM: 0.830898929387331
# File /home/Data/train/image/brain_acc8_110.h5, Average SSIM: 0.7751718716961997
# File /home/Data/train/image/brain_acc4_50.h5, Average SSIM: 0.815422210842371
# File /home/Data/train/image/brain_acc8_58.h5, Average SSIM: 0.7540247850120068
# File /home/Data/train/image/brain_acc4_31.h5, Average SSIM: 0.82580142095685
# File /home/Data/train/image/brain_acc5_112.h5, Average SSIM: 0.803356159478426
# File /home/Data/train/image/brain_acc4_69.h5, Average SSIM: 0.8094385266304016
# File /home/Data/train/image/brain_acc4_87.h5, Average SSIM: 0.8560379408299923
# File /home/Data/train/image/brain_acc5_100.h5, Average SSIM: 0.835549108684063
# File /home/Data/train/image/brain_acc8_96.h5, Average SSIM: 0.7761348895728588
# File /home/Data/train/image/brain_acc5_77.h5, Average SSIM: 0.8254387453198433
# File /home/Data/train/image/brain_acc5_36.h5, Average SSIM: 0.815671119838953
# File /home/Data/train/image/brain_acc8_89.h5, Average SSIM: 0.7743918411433697
# File /home/Data/train/image/brain_acc4_97.h5, Average SSIM: 0.8314629308879375
# File /home/Data/train/image/brain_acc8_82.h5, Average SSIM: 0.7824640944600105
# File /home/Data/train/image/brain_acc8_117.h5, Average SSIM: 0.7748957318919045
# File /home/Data/train/image/brain_acc5_10.h5, Average SSIM: 0.7951476648449898
# File /home/Data/train/image/brain_acc4_112.h5, Average SSIM: 0.8123595602810383
# File /home/Data/train/image/brain_acc5_54.h5, Average SSIM: 0.8115067668259144
# File /home/Data/train/image/brain_acc8_105.h5, Average SSIM: 0.7938178293406963
# File /home/Data/train/image/brain_acc8_43.h5, Average SSIM: 0.7837459221482277
# File /home/Data/train/image/brain_acc4_51.h5, Average SSIM: 0.8367703594267368
# File /home/Data/train/image/brain_acc8_8.h5, Average SSIM: 0.7542127221822739
# File /home/Data/train/image/brain_acc4_38.h5, Average SSIM: 0.8363039530813694
# File /home/Data/train/image/brain_acc8_87.h5, Average SSIM: 0.7488427571952343
# File /home/Data/train/image/brain_acc5_27.h5, Average SSIM: 0.8027693182229996
# File /home/Data/train/image/brain_acc8_91.h5, Average SSIM: 0.7351063564419746
# File /home/Data/train/image/brain_acc4_41.h5, Average SSIM: 0.8277381174266338
# File /home/Data/train/image/brain_acc5_38.h5, Average SSIM: 0.7882334999740124
# File /home/Data/train/image/brain_acc8_101.h5, Average SSIM: 0.7657869346439838
# File /home/Data/train/image/brain_acc5_105.h5, Average SSIM: 0.8029723279178143
# File /home/Data/train/image/brain_acc8_88.h5, Average SSIM: 0.7826545387506485
# File /home/Data/train/image/brain_acc8_113.h5, Average SSIM: 0.7777775600552559
# File /home/Data/train/image/brain_acc4_65.h5, Average SSIM: 0.8359735384583473
# File /home/Data/train/image/brain_acc5_60.h5, Average SSIM: 0.8299126923084259
# File /home/Data/train/image/brain_acc4_88.h5, Average SSIM: 0.8311310447752476
# File /home/Data/train/image/brain_acc5_22.h5, Average SSIM: 0.8070215433835983
# File /home/Data/train/image/brain_acc8_56.h5, Average SSIM: 0.7765481248497963
# File /home/Data/train/image/brain_acc8_52.h5, Average SSIM: 0.7751960344612598
# File /home/Data/train/image/brain_acc5_39.h5, Average SSIM: 0.8143903575837612
# File /home/Data/train/image/brain_acc4_24.h5, Average SSIM: 0.8137255199253559
# File /home/Data/train/image/brain_acc4_99.h5, Average SSIM: 0.8210403546690941
# File /home/Data/train/image/brain_acc4_93.h5, Average SSIM: 0.80350361764431
# File /home/Data/train/image/brain_acc5_98.h5, Average SSIM: 0.80235555768013
# File /home/Data/train/image/brain_acc8_45.h5, Average SSIM: 0.7831120938062668
# File /home/Data/train/image/brain_acc5_118.h5, Average SSIM: 0.8092349506914616
# File /home/Data/train/image/brain_acc8_70.h5, Average SSIM: 0.7606009431183338
# File /home/Data/train/image/brain_acc8_5.h5, Average SSIM: 0.7917909026145935
# File /home/Data/train/image/brain_acc8_63.h5, Average SSIM: 0.6254673711955547
# File /home/Data/train/image/brain_acc5_83.h5, Average SSIM: 0.8223579563200474
# File /home/Data/train/image/brain_acc5_108.h5, Average SSIM: 0.7963458225131035
# File /home/Data/train/image/brain_acc5_17.h5, Average SSIM: 0.8359852991998196
# File /home/Data/train/image/brain_acc4_111.h5, Average SSIM: 0.8082651011645794
# File /home/Data/train/image/brain_acc8_79.h5, Average SSIM: 0.7556487359106541
# File /home/Data/train/image/brain_acc8_22.h5, Average SSIM: 0.7565607093274593
# File /home/Data/train/image/brain_acc8_32.h5, Average SSIM: 0.7666065469384193
# File /home/Data/train/image/brain_acc4_62.h5, Average SSIM: 0.8367743119597435
# File /home/Data/train/image/brain_acc5_78.h5, Average SSIM: 0.7957365555422646
# File /home/Data/train/image/brain_acc8_81.h5, Average SSIM: 0.7490991875529289
# File /home/Data/train/image/brain_acc4_12.h5, Average SSIM: 0.8270846381783485
# File /home/Data/train/image/brain_acc4_8.h5, Average SSIM: 0.8389697521924973
# File /home/Data/train/image/brain_acc4_84.h5, Average SSIM: 0.8239962086081505
# File /home/Data/train/image/brain_acc5_88.h5, Average SSIM: 0.8005348816514015
# File /home/Data/train/image/brain_acc8_65.h5, Average SSIM: 0.7648894153535366
# File /home/Data/train/image/brain_acc8_42.h5, Average SSIM: 0.7913038618862629
# File /home/Data/train/image/brain_acc4_14.h5, Average SSIM: 0.8078210689127445
# File /home/Data/train/image/brain_acc4_19.h5, Average SSIM: 0.8570766746997833
# File /home/Data/train/image/brain_acc5_8.h5, Average SSIM: 0.8016615100204945
# File /home/Data/train/image/brain_acc4_54.h5, Average SSIM: 0.8308296017348766
# File /home/Data/train/image/brain_acc4_100.h5, Average SSIM: 0.8331647105515003
# File /home/Data/train/image/brain_acc8_60.h5, Average SSIM: 0.7563257478177547
# File /home/Data/train/image/brain_acc4_105.h5, Average SSIM: 0.8276269137859344
# File /home/Data/train/image/brain_acc4_115.h5, Average SSIM: 0.8217421881854534
# File /home/Data/train/image/brain_acc8_26.h5, Average SSIM: 0.7666999436914921
# File /home/Data/train/image/brain_acc4_25.h5, Average SSIM: 0.8219717629253864
# File /home/Data/train/image/brain_acc8_29.h5, Average SSIM: 0.7723590731620789
# File /home/Data/train/image/brain_acc8_2.h5, Average SSIM: 0.7589087672531605
# File /home/Data/train/image/brain_acc5_91.h5, Average SSIM: 0.7972959578037262
# File /home/Data/train/image/brain_acc5_89.h5, Average SSIM: 0.7963692285120487
# File /home/Data/train/image/brain_acc8_66.h5, Average SSIM: 0.7887270115315914
# File /home/Data/train/image/brain_acc5_79.h5, Average SSIM: 0.8020592480897903
# File /home/Data/train/image/brain_acc5_5.h5, Average SSIM: 0.8051102980971336
# File /home/Data/train/image/brain_acc8_72.h5, Average SSIM: 0.7809355221688747
# File /home/Data/train/image/brain_acc8_106.h5, Average SSIM: 0.7797405421733856
# File /home/Data/train/image/brain_acc4_73.h5, Average SSIM: 0.8293281942605972
# File /home/Data/train/image/brain_acc8_119.h5, Average SSIM: 0.7737431786954403
# File /home/Data/train/image/brain_acc5_102.h5, Average SSIM: 0.821189645677805
# File /home/Data/train/image/brain_acc4_78.h5, Average SSIM: 0.8077744357287884
# File /home/Data/train/image/brain_acc5_18.h5, Average SSIM: 0.8028613589704037
# File /home/Data/train/image/brain_acc8_86.h5, Average SSIM: 0.7631868980824947
# File /home/Data/train/image/brain_acc5_82.h5, Average SSIM: 0.8250796645879745
# File /home/Data/train/image/brain_acc5_26.h5, Average SSIM: 0.8074697814881802
# File /home/Data/train/image/brain_acc8_53.h5, Average SSIM: 0.7431237101554871
# File /home/Data/train/image/brain_acc8_108.h5, Average SSIM: 0.7599757271153587
# File /home/Data/train/image/brain_acc5_68.h5, Average SSIM: 0.8063723370432854
# File /home/Data/train/image/brain_acc4_118.h5, Average SSIM: 0.8044196031987667
# File /home/Data/train/image/brain_acc4_96.h5, Average SSIM: 0.8293261826038361
# File /home/Data/train/image/brain_acc4_2.h5, Average SSIM: 0.8304126486182213
# File /home/Data/train/image/brain_acc4_53.h5, Average SSIM: 0.848898746073246
# File /home/Data/train/image/brain_acc4_55.h5, Average SSIM: 0.8322782218456268
# File /home/Data/train/image/brain_acc4_30.h5, Average SSIM: 0.843411173671484
# File /home/Data/train/image/brain_acc8_71.h5, Average SSIM: 0.8010876998305321
# File /home/Data/train/image/brain_acc5_44.h5, Average SSIM: 0.8211885169148445
# File /home/Data/train/image/brain_acc5_48.h5, Average SSIM: 0.8342064507305622
# File /home/Data/train/image/brain_acc8_83.h5, Average SSIM: 0.7563155889511108
# File /home/Data/train/image/brain_acc5_25.h5, Average SSIM: 0.798167921602726
# File /home/Data/train/image/brain_acc5_41.h5, Average SSIM: 0.8153314590454102
# File /home/Data/train/image/brain_acc8_54.h5, Average SSIM: 0.7787389941513538
# File /home/Data/train/image/brain_acc5_94.h5, Average SSIM: 0.8106244541704655
# File /home/Data/train/image/brain_acc8_59.h5, Average SSIM: 0.7700280286371708
# File /home/Data/train/image/brain_acc4_36.h5, Average SSIM: 0.8240802027285099
# File /home/Data/train/image/brain_acc5_45.h5, Average SSIM: 0.8114060200750828
# File /home/Data/train/image/brain_acc5_69.h5, Average SSIM: 0.8076465204358101
# File /home/Data/train/image/brain_acc5_117.h5, Average SSIM: 0.8041215464472771
# File /home/Data/train/image/brain_acc8_94.h5, Average SSIM: 0.7548252567648888
# File /home/Data/train/image/brain_acc5_61.h5, Average SSIM: 0.7932709380984306
# File /home/Data/train/image/brain_acc4_108.h5, Average SSIM: 0.8351593464612961
# File /home/Data/train/image/brain_acc4_91.h5, Average SSIM: 0.8447658754885197
# File /home/Data/train/image/brain_acc5_65.h5, Average SSIM: 0.8131613954901695
# File /home/Data/train/image/brain_acc4_39.h5, Average SSIM: 0.8335498422384262
# File /home/Data/train/image/brain_acc8_73.h5, Average SSIM: 0.7458427213132381
# File /home/Data/train/image/brain_acc8_30.h5, Average SSIM: 0.750136986374855
# File /home/Data/train/image/brain_acc5_75.h5, Average SSIM: 0.8074306361377239
# File /home/Data/train/image/brain_acc8_95.h5, Average SSIM: 0.7578092403709888
# File /home/Data/train/image/brain_acc5_59.h5, Average SSIM: 0.7895213514566422
# File /home/Data/train/image/brain_acc5_52.h5, Average SSIM: 0.7931618504226208
# File /home/Data/train/image/brain_acc8_62.h5, Average SSIM: 0.7934800572693348
# File /home/Data/train/image/brain_acc4_77.h5, Average SSIM: 0.8133271560072899
# File /home/Data/train/image/brain_acc5_109.h5, Average SSIM: 0.7920973673462868
# File /home/Data/train/image/brain_acc5_110.h5, Average SSIM: 0.8233232982456684
# File /home/Data/train/image/brain_acc4_18.h5, Average SSIM: 0.8215621523559093
# File /home/Data/train/image/brain_acc5_85.h5, Average SSIM: 0.807365072625024
# File /home/Data/train/image/brain_acc4_20.h5, Average SSIM: 0.8267201222479343
# File /home/Data/train/image/brain_acc5_111.h5, Average SSIM: 0.8101816177368164
# File /home/Data/train/image/brain_acc8_28.h5, Average SSIM: 0.7772173980871836
# File /home/Data/train/image/brain_acc8_61.h5, Average SSIM: 0.7558717094361782
# File /home/Data/train/image/brain_acc8_37.h5, Average SSIM: 0.7656638026237488
# File /home/Data/train/image/brain_acc5_16.h5, Average SSIM: 0.8032963685691357
# File /home/Data/train/image/brain_acc5_53.h5, Average SSIM: 0.8016686514019966
# File /home/Data/train/image/brain_acc5_56.h5, Average SSIM: 0.8151918239891529
# File /home/Data/train/image/brain_acc8_13.h5, Average SSIM: 0.7852381654083729
# File /home/Data/train/image/brain_acc8_10.h5, Average SSIM: 0.7537318058311939
# File /home/Data/train/image/brain_acc5_51.h5, Average SSIM: 0.8216922022402287
# File /home/Data/train/image/brain_acc5_20.h5, Average SSIM: 0.7900075986981392
# File /home/Data/train/image/brain_acc4_70.h5, Average SSIM: 0.8438551463186741
# File /home/Data/train/image/brain_acc8_103.h5, Average SSIM: 0.7619958110153675
# File /home/Data/train/image/brain_acc8_99.h5, Average SSIM: 0.7663175761699677
# File /home/Data/train/image/brain_acc8_20.h5, Average SSIM: 0.7548787258565426
# File /home/Data/train/image/brain_acc5_97.h5, Average SSIM: 0.7984246537089348
# File /home/Data/train/image/brain_acc4_52.h5, Average SSIM: 0.8396138921380043
# File /home/Data/train/image/brain_acc8_23.h5, Average SSIM: 0.74844154343009
# File /home/Data/train/image/brain_acc8_104.h5, Average SSIM: 0.7543439865112305
# File /home/Data/train/image/brain_acc4_81.h5, Average SSIM: 0.8209274858236313
# File /home/Data/train/image/brain_acc8_118.h5, Average SSIM: 0.7704873904585838
# File /home/Data/train/image/brain_acc5_12.h5, Average SSIM: 0.8363499119877815
# File /home/Data/train/image/brain_acc4_76.h5, Average SSIM: 0.8049433939158916
# File /home/Data/train/image/brain_acc8_16.h5, Average SSIM: 0.7519504316151142
# File /home/Data/train/image/brain_acc5_6.h5, Average SSIM: 0.7864762805402279
# File /home/Data/train/image/brain_acc5_104.h5, Average SSIM: 0.8007955960929394
# File /home/Data/train/image/brain_acc4_94.h5, Average SSIM: 0.8397729620337486
# File /home/Data/train/image/brain_acc8_40.h5, Average SSIM: 0.7631442584097385
# File /home/Data/train/image/brain_acc5_19.h5, Average SSIM: 0.8008064366877079
# File /home/Data/train/image/brain_acc5_115.h5, Average SSIM: 0.7890106476843357
# File /home/Data/train/image/brain_acc5_33.h5, Average SSIM: 0.8000747784972191
# File /home/Data/train/image/brain_acc8_18.h5, Average SSIM: 0.7511068470776081
# File /home/Data/train/image/brain_acc4_79.h5, Average SSIM: 0.8107733391225338
# File /home/Data/train/image/brain_acc5_76.h5, Average SSIM: 0.8019571974873543
# File /home/Data/train/image/brain_acc5_72.h5, Average SSIM: 0.7778249606490135
# File /home/Data/train/image/brain_acc8_3.h5, Average SSIM: 0.7936281450092793
# File /home/Data/train/image/brain_acc4_23.h5, Average SSIM: 0.8230979293584824
# File /home/Data/train/image/brain_acc4_102.h5, Average SSIM: 0.8336298130452633
# File /home/Data/train/image/brain_acc8_17.h5, Average SSIM: 0.7571909166872501
# File /home/Data/train/image/brain_acc4_17.h5, Average SSIM: 0.8270115479826927
# File /home/Data/train/image/brain_acc5_4.h5, Average SSIM: 0.7942465394735336
# File /home/Data/train/image/brain_acc5_64.h5, Average SSIM: 0.822900578379631
# File /home/Data/train/image/brain_acc8_9.h5, Average SSIM: 0.7910067401826382
# File /home/Data/train/image/brain_acc4_95.h5, Average SSIM: 0.8307720236480236
# File /home/Data/train/image/brain_acc5_50.h5, Average SSIM: 0.8139162063598633
# File /home/Data/train/image/brain_acc4_68.h5, Average SSIM: 0.8295441195368767
# File /home/Data/train/image/brain_acc4_106.h5, Average SSIM: 0.8330002911388874
# File /home/Data/train/image/brain_acc8_109.h5, Average SSIM: 0.793663926422596
# File /home/Data/train/image/brain_acc5_9.h5, Average SSIM: 0.8318592198193073
# File /home/Data/train/image/brain_acc8_80.h5, Average SSIM: 0.7652420774102211
# File /home/Data/train/image/brain_acc5_23.h5, Average SSIM: 0.8278488293290138
# File /home/Data/train/image/brain_acc4_21.h5, Average SSIM: 0.8105180151760578
# File /home/Data/train/image/brain_acc8_33.h5, Average SSIM: 0.7675207704305649
# File /home/Data/train/image/brain_acc4_49.h5, Average SSIM: 0.8401796817779541
# File /home/Data/train/image/brain_acc4_37.h5, Average SSIM: 0.8489678427577019
# File /home/Data/train/image/brain_acc5_73.h5, Average SSIM: 0.7916129492223263
# File /home/Data/train/image/brain_acc8_67.h5, Average SSIM: 0.7579235471785069
# File /home/Data/train/image/brain_acc8_57.h5, Average SSIM: 0.779101487249136
# File /home/Data/train/image/brain_acc8_4.h5, Average SSIM: 0.7725460614476886
# File /home/Data/train/image/brain_acc8_78.h5, Average SSIM: 0.7510816119611263
# File /home/Data/train/image/brain_acc8_49.h5, Average SSIM: 0.7531698681414127
# File /home/Data/train/image/brain_acc5_1.h5, Average SSIM: 0.8249079175293446
# File /home/Data/train/image/brain_acc4_46.h5, Average SSIM: 0.7968975193798542
# File /home/Data/train/image/brain_acc8_46.h5, Average SSIM: 0.7601307332515717
# File /home/Data/train/image/brain_acc4_58.h5, Average SSIM: 0.8371972404420376
# File /home/Data/train/image/brain_acc4_6.h5, Average SSIM: 0.8287589214742184
# File /home/Data/train/image/brain_acc5_116.h5, Average SSIM: 0.8225347734987736
# File /home/Data/train/image/brain_acc5_63.h5, Average SSIM: 0.8088871538639069
# File /home/Data/train/image/brain_acc4_114.h5, Average SSIM: 0.828684326261282
# File /home/Data/train/image/brain_acc8_77.h5, Average SSIM: 0.7663415037095547
# File /home/Data/train/image/brain_acc5_66.h5, Average SSIM: 0.8081083260476589
# File /home/Data/train/image/brain_acc8_25.h5, Average SSIM: 0.7566675432026386
# File /home/Data/train/image/brain_acc5_47.h5, Average SSIM: 0.8201664984226227
# File /home/Data/train/image/brain_acc8_97.h5, Average SSIM: 0.7715181075036526
# File /home/Data/train/image/brain_acc8_27.h5, Average SSIM: 0.7670819014310837
# File /home/Data/train/image/brain_acc5_113.h5, Average SSIM: 0.7809487655758858
# File /home/Data/train/image/brain_acc8_51.h5, Average SSIM: 0.760299738496542
# File /home/Data/train/image/brain_acc5_31.h5, Average SSIM: 0.7903537265956402
# File /home/Data/train/image/brain_acc8_112.h5, Average SSIM: 0.7813360504806042
# File /home/Data/train/image/brain_acc5_24.h5, Average SSIM: 0.814105536788702
# File /home/Data/train/image/brain_acc4_11.h5, Average SSIM: 0.8541990108788013
# File /home/Data/train/image/brain_acc5_32.h5, Average SSIM: 0.7793121002614498
# File /home/Data/train/image/brain_acc5_71.h5, Average SSIM: 0.8074340634047985
# File /home/Data/train/image/brain_acc4_5.h5, Average SSIM: 0.8430079929530621
# File /home/Data/train/image/brain_acc5_103.h5, Average SSIM: 0.8016232401132584
# File /home/Data/train/image/brain_acc5_99.h5, Average SSIM: 0.8165626637637615
# File /home/Data/train/image/brain_acc5_34.h5, Average SSIM: 0.7960409745573997
# File /home/Data/train/image/brain_acc5_13.h5, Average SSIM: 0.8095759563148022
# File /home/Data/train/image/brain_acc4_59.h5, Average SSIM: 0.8245425410568714
# File /home/Data/train/image/brain_acc5_15.h5, Average SSIM: 0.8037148118019104
# File /home/Data/train/image/brain_acc4_90.h5, Average SSIM: 0.8224350549280643
# File /home/Data/train/image/brain_acc4_7.h5, Average SSIM: 0.8180631622672081
# File /home/Data/train/image/brain_acc4_48.h5, Average SSIM: 0.8250136561691761
# File /home/Data/train/image/brain_acc8_38.h5, Average SSIM: 0.7645344845950603
# File /home/Data/train/image/brain_acc5_30.h5, Average SSIM: 0.8203415088355541
# File /home/Data/train/image/brain_acc4_56.h5, Average SSIM: 0.8358095064759254
# File /home/Data/train/image/brain_acc5_3.h5, Average SSIM: 0.8112753704190254
# File /home/Data/train/image/brain_acc8_84.h5, Average SSIM: 0.7803238965570927
# File /home/Data/train/image/brain_acc5_96.h5, Average SSIM: 0.8110322207212448
# Overall Average SSIM across all processed files: 0.8002
